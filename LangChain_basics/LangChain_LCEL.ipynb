# %% [markdown]
# ### LCEL Chain with custom formatting
# - LangChain Expression Language

# %%
# %%capture
# %pip install "langchain==0.2.11" --user
# %pip install "langchain-core==0.2.43" --user
# Out:
# ...
#   Using cached async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 2.3 MB/s eta 0:00:00a 0:00:01
# ...
#   Using cached tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.1/75.1 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 kB 1.1 MB/s eta 0:00:00
# ...
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.7/190.7 kB 4.2 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 990.3/990.3 kB 12.3 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 496.1/496.1 kB 11.8 MB/s eta 0:00:0000:01
# ...

# %%
# restart kernel
